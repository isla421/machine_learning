# %%
import seaborn as sns
import pandas as pd
from statsmodels.tsa.seasonal import STL

# %%
# sns.get_dataset_names()
df = sns.load_dataset('flights')
df['day'] = 1
df['month'] = df.month.map({
    'Jan': 1, 'Feb': 2, 'Mar': 3, 'Apr': 4, 'May': 5, 'Jun': 6,
    'Jul': 7, 'Aug': 8, 'Sep': 9, 'Oct': 10, 'Nov': 11, 'Dec': 12
})
df.set_index(pd.to_datetime(df[['year', 'month', 'day']]), inplace=True)
df.head()
# Out:
#             year month  passengers  day
# 1949-01-01  1949     1         112    1
# 1949-02-01  1949     2         118    1
# 1949-03-01  1949     3         132    1
# 1949-04-01  1949     4         129    1
# 1949-05-01  1949     5         121    1

# %%
stl = STL(df.passengers, seasonal=13)
res = stl.fit()
fig = res.plot()
